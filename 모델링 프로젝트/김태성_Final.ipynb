# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
submission = pd.read_csv('./pubg-finish-placement-prediction/sample_submission_V2.csv')
test = pd.read_csv('./pubg-finish-placement-prediction/test_V2.csv')
train = pd.read_csv('./pubg-finish-placement-prediction/train_V2.csv')

# %%
def toVIF(features): 
    return pd.DataFrame({
        "feature": features.columns,
        "VIF": [variance_inflation_factor(features.values, idx)
                for idx in range(features.shape[1])]
    })

# %%
train = train.dropna(axis=0)

# %%
features = train[['assists', 'boosts', 'damageDealt', 'DBNOs', 'headshotKills', 'heals',
       'killPlace', 'kills', 'killStreaks', 'longestKill', 'matchDuration',
       'maxPlace', 'numGroups', 'revives', 'rideDistance',
       'roadKills', 'swimDistance', 'teamKills', 'vehicleDestroys',
       'walkDistance', 'weaponsAcquired',]]
toVIF(features)
# Out:
#             feature          VIF
# 0           assists     1.489376
# 1            boosts     3.282047
# 2       damageDealt     9.623737
# 3             DBNOs     3.733941
# 4     headshotKills     2.128095
# 5             heals     1.884647
# 6         killPlace    12.389289
# 7             kills    10.912135
# 8       killStreaks     6.228125
# 9       longestKill     2.078603
# 10    matchDuration    28.419906
# 11         maxPlace  1104.833987
# 12        numGroups  1081.728009
# 13          revives     1.309480
# 14     rideDistance     1.577476
# 15        roadKills     1.021854
# 16     swimDistance     1.054247
# 17        teamKills     1.045890
# 18  vehicleDestroys     1.041166
# 19     walkDistance     4.704274
# 20  weaponsAcquired     4.853294

# %%
features = train[['assists', 'boosts', 'DBNOs', 'headshotKills', 'heals',
        'kills', 'killStreaks', 'longestKill', 'matchDuration',
       'maxPlace', 'revives', 'rideDistance',
       'roadKills', 'swimDistance', 'teamKills', 'vehicleDestroys',
       'walkDistance', 'weaponsAcquired',]]
toVIF(features)
# Out:
#             feature       VIF
# 0           assists  1.403776
# 1            boosts  3.250209
# 2             DBNOs  3.267343
# 3     headshotKills  2.122028
# 4             heals  1.877066
# 5             kills  7.112348
# 6       killStreaks  4.657251
# 7       longestKill  2.068384
# 8     matchDuration  8.024791
# 9          maxPlace  5.080850
# 10          revives  1.308082
# 11     rideDistance  1.462237
# 12        roadKills  1.021574
# 13     swimDistance  1.054031
# 14        teamKills  1.044035
# 15  vehicleDestroys  1.041090
# 16     walkDistance  4.276048
# 17  weaponsAcquired  4.779106
